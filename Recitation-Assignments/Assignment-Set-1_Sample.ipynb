# %% [markdown]
# # Assignment Set 1 by [Your_Name] for [Applied Machine Learning/Deep Learning] Course at Data Science Center, SBU

# %%
# !hostname
# !whoami
# Out:
# yty-desktop
# yty

# %%
import sys
from datetime import datetime
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import sklearn

# %%
print(datetime.now(), time.localtime().tm_zone, 'UTC')
# Out:
# 2021-11-13 13:25:11.805038 +0330 UTC

# %%
sys.version
# Out:
# '3.7.4 (default, Aug 13 2019, 20:35:49) \n[GCC 7.3.0]'

# %%
start_time = time.time()
data = {'a': np.arange(500),
        'c': np.random.randint(0, 500, 500),
        'd': 0.3*np.random.randn(500)}
data['b'] = data['a'] + 10 * np.random.randn(500)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
df = pd.DataFrame(np.random.randn(10, 4)) 
print(df)

j=1.23
for i in range(80000000):
  j+=j**0.8157678

print("\n-> Execution time was %s seconds <-" % (time.time() - start_time))
# Out:
#           0         1         2         3
# 0 -0.586722 -0.207000 -1.308758 -0.152165
# 1  1.272038  0.636308 -1.372132  1.016271
# 2 -0.823139  1.236532  1.577816 -0.646164
# 3  1.123740 -0.419440 -0.106504 -0.279846
# 4 -0.117574  2.853033 -0.921138  0.908544
# 5 -1.191960  1.204705  1.950481  0.557829
# 6 -1.237749  0.478574  0.637579  0.850902
# 7  0.913900  0.378192  1.484584  1.380534
# 8  0.611769  0.156439 -0.678460  0.815976
# 9  0.120389  0.706875 -0.713905 -0.130221
#
# -> Execution time was 11.725935935974121 seconds <-
