# %% [markdown]
# #  k-Nearest-Neighbors
# Using an algorithm in Sklearn, we generate a k-Nearest-Neighbors as follows:

# %% [markdown]
# First, we should import the required modules as follows:

# %%
import sklearn.datasets as datasets
from sklearn import metrics, model_selection, preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import set_option
from mlxtend.plotting import plot_learning_curves
from mlxtend.plotting import plot_decision_regions
# %matplotlib inline

# %% [markdown]
# # Load the Iris Data and Explore it

# %%
# Load data as DataFrame
df = pd.read_csv('Data/iris.csv')

# %%
# Check the shape of DataFrame
df.shape
# Out:
# (150, 5)

# %%
# Show the top five rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Show the information of DataFrame (Data Columns, Types, ...)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
# Set the decimal precision
set_option('precision', 2)
# Generate descriptive statistics  
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count        150.00       150.00        150.00       150.00
# mean           5.84         3.06          3.76         1.20
# std            0.83         0.44          1.77         0.76
# min            4.30         2.00          1.00         0.10
# 25%            5.10         2.80          1.60         0.30
# 50%            5.80         3.00          4.35         1.30
# 75%            6.40         3.30          5.10         1.80
# max            7.90         4.40          6.90         2.50

# %%
# Verify there is no missing value in data
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Check the number of classes in target 
df.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Check target for imbalanced classes
df.species.value_counts()
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
# Using the following code, one can convert the target column to Numeric
df['class_label'] = df.species.map({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})
#
# Alternative Method:
# df['class_label']= pd.factorize(df['species'])[0]
# df['class_label'], _= pd.factorize(df['class'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  \
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
#
#    class_label
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Box plot of all numeric columns, grouped by species
feature=["sepal_length", "sepal_width", "petal_length", "petal_width"]
df.boxplot(column=feature, by='species', rot=45, figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a149c49b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a05198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a19a33208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19a5b278>]],
#       dtype=object)

# %%
# Scatter matrix of all features, colored by species
pd.plotting.scatter_matrix(df.drop(["species", "class_label"], axis=1), c=df.class_label, figsize=(12, 12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d0c34a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d0ea7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d112e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d141518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d169ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d169be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d1c3908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d1ecf98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d21f668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d245cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d2783c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d29ea58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d2d2128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d2f97b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d322e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d355518>]],
#       dtype=object)

# %%
# Drop target column
feature=["sepal_length", "sepal_width", "petal_length", "petal_width"]
X=df[feature]
#
## Alternative Method
# X= df.drop(["species", "class_label"], axis=1)
#
y=df["class_label"]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class_label, dtype: int64

# %%
# Get the correlations between features
correlations = df.corr(method='pearson')
set_option('display.width', 150)
correlations
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  class_label
# sepal_length          1.00        -0.12          0.87         0.82         0.78
# sepal_width          -0.12         1.00         -0.43        -0.37        -0.43
# petal_length          0.87        -0.43          1.00         0.96         0.95
# petal_width           0.82        -0.37          0.96         1.00         0.96
# class_label           0.78        -0.43          0.95         0.96         1.00

# %% [markdown]
# ### Standardize the Features

# %%
# Is it necessary to standardize the features in  k-Nearest-Neighbors? Yes!
sc = preprocessing.StandardScaler()
sc.fit(X)
X= sc.transform(X)

# %%
## If training set and test set are different DataFrame
# sc = preprocessing.StandardScaler()
# sc.fit(X_train)
# X_train= sc.transform(X_train)
# X_test= sc.transform(X_test)

# %% [markdown]
# ## Train and Test Sets

# %%
# split data randomly into 70% training and 30% test
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Tain the Model

# %%
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(3, weights = 'uniform')
trained_model = clf.fit(X, y)

# %% [markdown]
# ## Make Predictions

# %% [markdown]
# Now, one can use this model to predict the test data

# %%
y_pred = clf.predict(X_test)

# %% [markdown]
# ## Evaluate the Model

# %%
# Count the number of misclassifications
count_misclassified = (y_test != y_pred).sum()
print('Misclassified samples: {}'.format(count_misclassified))
# Out:
# Misclassified samples: 2

# %%
# Evaluate accuracy
accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}'.format(accuracy))
# Out:
# Accuracy: 0.96

# %% [markdown]
# ## Learning Curve

# %%
# Create training and test scores for various training set sizes
clf = neighbors.KNeighborsClassifier(3, weights = 'uniform')
plot_learning_curves(X_train, y_train, X_test, y_test, clf, print_model=False, style='ggplot')
# Out:
# ([0.2,
#   0.09523809523809523,
#   0.06451612903225806,
#   0.047619047619047616,
#   0.019230769230769232,
#   0.047619047619047616,
#   0.0410958904109589,
#   0.03571428571428571,
#   0.031914893617021274,
#   0.02857142857142857],
#  [0.6,
#   0.4888888888888889,
#   0.06666666666666667,
#   0.06666666666666667,
#   0.06666666666666667,
#   0.06666666666666667,
#   0.022222222222222223,
#   0.022222222222222223,
#   0.022222222222222223,
#   0.022222222222222223])

# %% [markdown]
# #### Learning Curve (Alternative Method)

# %%
# Create training and test scores for various training set sizes
from sklearn.model_selection import learning_curve
clf = neighbors.KNeighborsClassifier(3, weights = 'uniform')

train_sizes, train_scores, test_scores = learning_curve(clf, X, y, cv=5, scoring='accuracy', 
                                                        train_sizes=np.linspace(0.3, 1.0, 5))

# Create means of training set scores and test set scores
train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size")
plt.ylabel("Accuracy Score")
plt.legend(loc="best")
plt.tight_layout()

# %% [markdown]
# ## Visualize the Model's Decision Regions

# %%
feature_selected=["petal_length", "petal_width"]
X_2=df[feature_selected]
y_2=df["class_label"]

# %% [markdown]
# #### Train the Model Again!

# %%
clf = neighbors.KNeighborsClassifier(3, weights = 'uniform')
clf.fit(X_2,y_2)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %% [markdown]
# ### Convert DataFrame to Numpy Array

# %%
X_2=np.array(X_2)
y_2=np.array(y_2)

# %%
X_2.shape
# Out:
# (150, 2)

# %% [markdown]
# ## Decision Regions

# %%
from mlxtend.plotting import plot_decision_regions 
plot_decision_regions(X_2, y_2, clf=clf, legend=2)
plt.xlabel('petal length')
plt.ylabel('petal width')
plt.legend(loc='lower right')
